# %% [markdown]
# <a href="https://colab.research.google.com/github/andrewhslr419/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/Andrew_1_2_assignment_ds11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>

# %% [markdown]
# # Assignment:
#
# - Replicate the lesson code.
#
#  - This means that if you haven't followed along already, type out the things that we did in class. Forcing your fingers to hit each key will help you internalize the syntax of what we're doing. Make sure you understand each line of code that you're writing, google things that you don't fully understand.
#  - [Lambda Learning Method for DS - By Ryan Herr](https://docs.google.com/document/d/1ubOw9B3Hfip27hF2ZFnW3a3z9xAgrUDRReOEo-FHCVs/edit?usp=sharing)
# - Convert the `term` column from string to integer.
# - Make a column named `loan_status_is_great`. It should contain the integer 1 if `loan_status` is "Current" or "Fully Paid." Else it should contain the integer 0.
# - Make `last_pymnt_d_month` and `last_pymnt_d_year` columns.

# %%
# !wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Out:
# --2019-12-03 23:03:45--  https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip
# Resolving resources.lendingclub.com (resources.lendingclub.com)... 64.48.1.20
# Connecting to resources.lendingclub.com (resources.lendingclub.com)|64.48.1.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘LoanStats_2018Q4.csv.zip.1’
#
# LoanStats_2018Q4.cs     [           <=>      ]  21.69M   408KB/s    in 56s
#
# 2019-12-03 23:04:41 (397 KB/s) - ‘LoanStats_2018Q4.csv.zip.1’ saved [22744357]
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-70-3f67f69e2c50> in <module>()
# ----> 1 get_ipython().system('wget https://resources.lendingclub.com/LoanStats_2018Q4.csv.zip')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
# ...

# %%
#!unzip LoanStats_2018Q4.csv.zip
# !unzip LoanStats_2018Q4.csv.zip

# %%
#!head LoanStats_2018Q4.csv
# !head LoanStats_2018Q4.csv

# %%
# !tail LoanStats_2018Q4.csv

# %%
df = pd.read_csv('LoanStats_2018Q4.csv')
print(df.shape)
df.head()

# %%
# Sum null values by column and sort from least to greatest
# pd.set_option('display.max_rows', 200)

# df.isnull().sum().sort_values()
pd.set_option('display.max_rows', 200)
df.isnull().sum().sort_values()

# %%
# df = pd.read_csv('LoanStats_2018Q4.csv', header=1, skipfooter=2, engine='python')
# print(df.shape)
# df.head()
df=pd.read_csv('LoanStats_2018Q4.csv', header=1,skipfooter=2, engine='python')
print(df.shape)
df.head()

# %%
df.isnull().sum().sort_values()

# %%
# drop the 100% blank columns

# df = df.drop(['url', 'member_id', 'desc', 'id'], axis=1)
df=df.drop(['url', 'member_id', 'desc', 'id'], axis=1)

# %%
# Look at the first 10 values of the int_rate column
# df['int_rate'].head(10)
df['int_rate'].head(10)

# %%
df['int_rate'][0:10]

# %%
df['int_rate'][3:7]

# %%
df['int_rate'][:-3]

# %%
int_rate = ' 14.17%'

# %%
int_rate.strip()

# %%
int_rate.strip('%')

# %%
int_rate.strip().strip('%')

# %%
# check the value of our variable after the characters have been stripped
# type(int_rate.strip().strip('%'))
type(int_rate.strip().strip('%'))

# %%
float(int_rate.strip().strip('%'))

# %%
type(float(int_rate.strip().strip('%')))

# %%
# Write a function that can do what we have written above to any 
# string that is passsed to it.
# def int_rate_to_float(cell_contents):
#   return float(cell_contents.strip().strip('%'))

def int_rate_to_float(cell_contents):
  return float(cell_contents.strip().strip('%'))

# %%
int_rate_to_float(int_rate)

# %%
type(int_rate_to_float(int_rate))

# %%
# new_list = []
# for cell in df['int_rate']:
#   new_list.append(int_rate_to_float(cell))

# df['int_rate_cleaned'] = pd.Series(new_list)
new_list=[]
for cell in df['int_rate']:
  new_list.append(int_rate_to_float(cell))
df['int_rate_cleaned']=pd.Series(new_list)

# %%
# What type of data is held in our new column?

# df['int_rate_float'] = df['int_rate'].apply(int_rate_to_float)

# df.head()
df['int_rate_to_float']=df['int_rate'].apply(int_rate_to_float)
df.head()

# %%
df.dtypes[-5:]

# %%
'''Creating a new column I had to add and drop some columns to get it right'''
def loan_status_is_great (loan_status_is_great):
  df['loan_status_is_great'].value_counts(dropna=False)[:20]

# %%
def loan_status_is_great(job_title):
  if loan_status == ('Current'):
    print(1)
  else:
    print(0)

# %%
df['loan_status_is_great'] = 'Value'

# %%
df.dropna()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df.drop('Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)', axis='columns')
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df.drop('new feature', axis='columns')
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
import pandas as pd
# Lets take a look at the Ames Iowa Housing Dataset:
df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv')

# %%
# print(df.shape)
# df.head()
# print(df.shape)
# df.head()

# %%
# pd.set_option('display.max_rows', 100)

# df.dtypes
pd.set_option('display.max_rows', 100)
df.dtypes

# %%
df = pd.read_csv('LoanStats_2018Q4.csv')
print(df.shape)
df.head()

# %%
def f('loan_status_func'):
    if df['loan_statis'] == ['Current']:
        df.apply('1', axis=1)
    elif df['loan_status'] == ['Fully Pain']:
        df.apply('1', axis=1)
    else:
        df.apply('0', axis = 1)
    return val
# Out:
#   File "<ipython-input-1-dd30e0efa316>", line 1
#     def f('loan_status_func'):
#                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# Make a column named loan_status_is_great. It should contain the integer 1 if loan_status is "Current" or "Fully Paid." Else it should contain the integer 0.

# %% [markdown]
# # Stretch Goals
#
# You can do more with the LendingClub or Instacart datasets.
#
# LendingClub options:
# - There's one other column in the dataframe with percent signs. Remove them and convert to floats. You'll need to handle missing values.
# - Modify the `emp_title` column to replace titles with 'Other' if the title is not in the top 20.
# - Take initiatve and work on your own ideas!
#
# Instacart options:
# - Read [Instacart Market Basket Analysis, Winner's Interview: 2nd place, Kazuki Onodera](http://blog.kaggle.com/2017/09/21/instacart-market-basket-analysis-winners-interview-2nd-place-kazuki-onodera/), especially the **Feature Engineering** section. (Can you choose one feature from his bulleted lists, and try to engineer it with pandas code?)
# - Read and replicate parts of [Simple Exploration Notebook - Instacart](https://www.kaggle.com/sudalairajkumar/simple-exploration-notebook-instacart). (It's the Python Notebook with the most upvotes for this Kaggle competition.)
# - Take initiative and work on your own ideas!

# %% [markdown]
# You can uncomment and run the cells below to re-download and extract the Instacart data

# %%
# !wget https://s3.amazonaws.com/instacart-datasets/instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# !tar --gunzip --extract --verbose --file=instacart_online_grocery_shopping_2017_05_01.tar.gz

# %%
# %cd instacart_2017_05_01
